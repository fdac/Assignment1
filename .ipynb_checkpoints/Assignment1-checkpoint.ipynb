# %% [markdown]
# # Written text as operational data
#
# Written text is one type of data
#
# ### Why people write?
#
#  - To communicate: their thoughts, feelings, urgency, needs, information
#
# ### Why people communicate?
#
# 1. To express emotions
# 1. To share information
# 1. To enable or elicit an action
# 1. ...
#
# ### We will use written text for the purpose other than
# 1. To experience emotion
# 1. To learn something the author intended us to learn
# 1. To do what the author intended us to do
#
# ### Instead, we will use written text to recognize who wrote it
#  - By calculating and comparing word frequencies in written documents

# %% [markdown]
# ### Example 1. Dictionaries in python (associative arrays)
#
# Plot the frequency distribution of words on a web page.

# %%
import requests, re
# re is a module for regular expressions: to detect various combinations of characters
import operator

# Start from a simple document
r = requests .get('http://eecs.utk.edu')

# What comes back includes headers and other HTTP stuff, get just the body of the response
t = r.text

# obtain words by splitting a string using as separator one or more (+) 
# space/like characters (\s) 
wds = re.split('\s+',t)

# now populate a dictionary (wf)
wf = {}
for w in wds:
    if w in wf: wf [w] = wf [w] + 1
    else:  wf[w] = 1
print wf
g = 5
p = 10
print g+p
# dictionaries can not be sorted, so lets get a sorted *list*        
wfs = sorted (wf .iteritems(), key = operator .itemgetter (1), reverse=True)   

# lets just have no more than 15 words 
ml = min(len(wfs),15)
for i in range(1,ml,1):
    print wfs[i][0]+"\t"+str(wfs[i][1])
# Out:
# {u'': 1, u'!function(d,s,id){var': 1, u'class="placeholder">People</a><ul><li><a': 1, u'<hr>': 2, u'>Course': 3, u'Team"></a>': 1, u'37996': 1, u'title="Majors': 3, u'<h2>Upcoming': 1, u'::': 1, u'Department': 4, u'target="_self">New': 1, u'[];': 1, u'Supporting': 1, u'href="http://www.eecs.utk.edu/about-eecs/visitor-information/">Visitor': 1, u'drawing/drafting': 1, u'ccm-search-block-submit">': 1, u'id="getFeed">': 1, u's.parentNode.insertBefore(ga,': 1, u'Award': 2, u'to': 4, u'class="wide': 1, u'content="IE=edge,chrome=IE8">': 1, u'class="footer-map">': 1, u'Eight': 1, u'target="_self">Underwriters': 1, u'Social!</h2>': 1, u'Day': 2, u'Classes/Timetable</a></li><li><a': 1, u'closed.</div>': 1, u'class="breadcrumbs">': 1, u'DIRECTORY</a></li>': 5, u'true;': 1, u'Tennessee,': 3, u'question</a></li>': 1, u'Microelectronics': 1, u'id="tools"': 1, u'href="/academics/majors-offered/#ce">Computer': 1, u'id="nav1-h"': 1, u'href="#MAIL:&#105;&#110;&#102;&#111;&#40;&#97;&#116;&#41;&#101;&#101;&#99;&#115;&#46;&#117;&#116;&#107;&#46;&#101;&#100;&#117;">Ask': 1, u'target="_blank">Get': 1, u'join': 1, u'>Areas': 1, u'href="/people/industrial-advisory-board/"': 1, u'<h2>Welcome': 1, u'impressive': 1, u'title="RSS"': 1, u'Services</a></li>': 1, u'lang="en"><!--<![endif]-->': 1, u'Competition': 1, u'href="https://www.eecs.utk.edu/utk_login?rcID=%2F">EECS': 1, u'>CURENT</a></li></ul></li><li><a': 1, u'Program</a></span>': 1, u'href="http://www.utk.edu/alpha/#A-E"': 1, u'science': 1, u'Breakfast': 1, u'</ul>': 16, u'9/1/2014': 1, u'href="/people/students/"': 1, u'<script': 9, u'class="no-js': 4, u'ga': 1, u'CCM_IMAGE_PATH': 1, u'alt="Min': 1, u'</div><!--': 1, u'href="http://www.eecs.utk.edu/resources/employment/">Employment': 1, u'Directory</a></li>': 1, u'(IE': 2, u'levels.': 1, u'oldie"': 3, u'Join': 1, u'>Majors': 1, u'CALENDAR</a></li>': 2, u'column': 2, u'Student,': 1, u'CCM_ARRANGE_MODE': 1, u'combined': 1, u'<h1': 2, u'CCM_TOOLS_PATH': 1, u'(homepage': 1, u'searchfield': 1, u'class="two-thirds': 1, u'src="/themes/utk_2012_vertical/js/html5-shiv.js"></script><![endif]-->': 1, u'id="toolbox">': 1, u'INSTITUTE</a></li>': 1, u'http-equiv="X-UA-Compatible"': 1, u'<li><span': 1, u'designing': 2, u'new': 1, u'Curriculum</a></li><li><a': 1, u'Information</a></li><li><a': 1, u'Heritage': 1, u'target="_blank">UT': 5, u'alt="UTK': 1, u'<form': 1, u'Organizations</a></li></ul></li><li><a': 1, u'degree': 1, u'class="footer-column">': 2, u'href="http://tntoday.utk.edu/2014/03/24/engineering-helping-robotic-football-kickoff/">UT\u2019s': 1, u'Professor': 1, u'href="/updates/concrete5.6.3.1_updater/concrete/css/ccm.base.css"': 1, u'the\xa0<span>IEEE': 1, u'target=""><img': 4, u'ICL': 1, u'Design</a></li><li><a': 1, u'>Department': 1, u'".flexslider_block2433"': 1, u'more</a></figcaption>': 1, u'865-974-1000<br>': 1, u'System</a></p>': 1, u'Device</a></li>': 1, u'href="http://www.utk.edu/tntoday/2013/08/07/personal-computer-inventor-join-engineering-faculty/"': 3, u'href="http://www.utk.edu/maps/"': 1, u'Energy': 2, u'class="HTMLBlock">': 1, u"$('.flexslider_block2433').flexslider({": 1, u'id="n7"><a>LIBRARIES</a>': 1, u'recently': 1, u'</h1>': 1, u'Place': 1, u'{': 2, u'none;"': 6, u'class="BasicParagraph">Though': 1, u'href="http://www.eecs.utk.edu/news/tackling-technical-interview">Tackling': 1, u'<div>': 1, u'CCM_CID': 1, u'Member': 1, u'1st': 1, u'>Business': 1, u'style="font-size:': 3, u'alt="CISML': 1, u'</nav>': 1, u'method="get"': 1, u'from': 3, u'working': 1, u'target="_blank">CHANCELLOR</a></li>': 1, u'Awarded': 1, u'Express': 1, u'title="Website': 1, u'next': 1, u'<h3><a': 1, u'</footer>': 1, u'src="/updates/concrete5.6.3.1_updater/concrete/js/ccm.base.js"></script>': 1, u'Awards': 1, u'Researchers': 1, u'href="http://fonts.googleapis.com/css?family=Shadows+Into+Light+Two">': 1, u'Library</a></li>': 1, u'"/index.php/tools/required";': 1, u'is': 5, u'nav-path-selected"': 1, u'9)': 1, u'DEANS</a></li>': 1, u'VET': 1, u'LISTSERV</a></li>': 1 ...
# 15
# <div	51
# </div>	38
# of	33
# the	23
# and	20
# <a	17
# </ul>	16
# Computer	16
# Engineering	15
# =	14
# </li>	14
# in	12
# a	11
# var	11

# %% [markdown]
# ### Example 2
#
# Lots of markup in the output, lets remove it ---
#
# use BeautifulSoup and nltk modules and practice some regular expressions.

# %%
import requests, re, nltk
from BeautifulSoup import BeautifulStoneSoup
from nltk import clean_html
from collections import Counter
import operator

# we may not care about the usage of stop words
nltk .download ('stopwords')
stop_words = nltk.corpus.stopwords.words('english') + [
 'ut', '\'re','.', ',', '--', '\'s', '?', ')', '(', ':', '\'',
 '\"', '-', '}', '{', '&', '|', u'\u2014' ]

# We most likely would like to remove html markup
def cleanHtml (html):
    return BeautifulStoneSoup(clean_html(html),
                convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]

# We also want to remove special characters, quotes, etc. from each word
def cleanWord (w):
    # r in r'[.,"\']' stands for regular expression
    # any character between the brackets [] is to be removed 
    return re.sub(r'[.,"\.]', "", w)
       
# define a function to get text/clean/calculate frequency
def get_wf (URL):
    # first get the web page
    r = requests .get(URL)
    
    # Now clean
    # remove html markup
    t = cleanHtml (r .text) .lower()
    
    # split string into an array of words using any sequence of spaces "\s+" 
    wds = re .split('\s+',t)
    
    # remove periods, commas, etc stuck to the edges of words
    for i in range(len(wds)):
        wds [i] = cleanWord (wds [i])
    
    # If satisfied with results, lets go to the next step: calculate frequencies
    # We can write a loop to create a dictionary, but 
    # there is a special function for everything in python
    # in particular for counting frequencies (like function table() in R)
    wf = Counter (wds)
    
    # Remove stop words from the dictionary wf
    for k in stop_words:
        wf. pop(k, None)
    
    # Get ordered list
    wfs = sorted (wf .iteritems(), key = operator.itemgetter(1), reverse=True)
    ml = min(len(wfs),15)

    #Reverse the list because barh plots items from the bottom
    return wfs [ 1:ml ] [::-1]
        
# Now populate two lists    
wf_ee = get_wf('http://eecs.utk.edu')
wf_bu = get_wf('http://bus.utk.edu')
print wf_bu
# Out:
# [nltk_data] Downloading package 'stopwords' to /home/cosc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [(u'give', 3), (u'supply', 3), (u'event', 3), (u'rankings', 3), (u'chain', 3), (u'information', 4), (u'programs', 4), (u'calendar', 4), (u'management', 5), (u'tennessee', 5), (u'knoxville', 5), (u'university', 5), (u'academic', 6), (u'business', 6)]

# %%
#Plot the results: are there striking differences in language?
import numpy as np
import pylab
import matplotlib.pyplot as plt

# %matplotlib inline
def plotTwoLists (wf_ee, wf_bu, title):
    f = plt.figure (figsize=(10, 6))
    # this is painfully tedious....
    f .suptitle (title, fontsize=20)
    ax = f.add_subplot(111)
    ax .spines ['top'] .set_color ('none')
    ax .spines ['bottom'] .set_color ('none')
    ax .spines ['left'] .set_color ('none')
    ax .spines ['right'] .set_color ('none')
    ax .tick_params (labelcolor='w', top='off', bottom='off', left='off', right='off', labelsize=20)

    # Create two subplots, this is the first one
    ax1 = f .add_subplot (121)
    plt .subplots_adjust (wspace=.5)

    pos = np .arange (len(wf_ee)+1) 
    ax1 .tick_params (axis='both', which='major', labelsize=14)
    pylab .yticks (pos, [ x [0] for x in wf_ee ])
    ax1 .barh (range(len(wf_ee)), [ x [1] for x in wf_ee ], align='center')

    ax2 = f .add_subplot (122)
    ax2 .tick_params (axis='both', which='major', labelsize=14)
    pos = np .arange (len(wf_bu)+1) 
    pylab .yticks (pos, [ x [0] for x in wf_bu ])
    ax2 .barh (range (len(wf_bu)), [ x [1] for x in wf_bu ], align='center')

plotTwoLists (wf_ee, wf_bu, 'Most Frequent Words From Two Departments')

# %% [markdown]
# # Assignment 1
#
# 1. Compare word frequencies between two works of a single author.
# 1. Compare word frequencies between works of two authors.
# 1. Are there some words preferred by one author but used less frequently by another author?
#
# Project Gutenberg is a good source of for fiction and non-fiction.
#
# E.g below are two most popular books from Project Gutenberg:
# - Pride and Prejudice at http://www.gutenberg.org/ebooks/1342.txt.utf-8
# - Adventures of Huckleberry Finn at http://www.gutenberg.org/ebooks/76.txt.utf-8

# %% [markdown]
# # Problem 1
# The following code compares Darwin's Origin of Species to his
# Journey of the Beagle

# %%
import requests, re, nltk
from BeautifulSoup import BeautifulStoneSoup
from nltk import clean_html
from collections import Counter
import operator

# we may not care about the usage of stop words
nltk .download ('stopwords')
stop_words = nltk.corpus.stopwords.words('english') + [
 'ut', '\'re','.', ',', '--', '\'s', '?', ')', '(', ':', '\'',
 '\"', '-', '}', '{', '&', '|', u'\u2014','[',']','__',' ' ]

# We most likely would like to remove html markup
def cleanHtml (html):
    return BeautifulStoneSoup(clean_html(html),
                convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]

# We also want to remove special characters, quotes, etc. from each word
def cleanWord (w):
    # r in r'[.,"\']' stands for regular expression
    # any character between the brackets [] is to be removed 
    return re.sub(r'[.,"\.]', "", w)
       
# define a function to get text/clean/calculate frequency
def get_wf (URL):
    # first get the web page
    r = requests .get(URL)
    
    # Now clean
    # remove html markup
    t = cleanHtml (r .text) .lower()
    
    # split string into an array of words using any sequence of spaces "\s+" 
    wds = re .split('\s+',t)
    
    # remove periods, commas, etc stuck to the edges of words
    for i in range(len(wds)):
        wds [i] = cleanWord (wds [i])
    
    # If satisfied with results, lets go to the next step: calculate frequencies
    # We can write a loop to create a dictionary, but 
    # there is a special function for everything in python
    # in particular for counting frequencies (like function table() in R)
    wf = Counter (wds)
    
    # Remove stop words from the dictionary wf
    for k in stop_words:
        wf. pop(k, None)
    
    # Get ordered list
    wfs = sorted (wf .iteritems(), key = operator.itemgetter(1), reverse=True)
    ml = min(len(wfs),15)

    #Reverse the list because barh plots items from the bottom
    return wfs [ 1:ml ] [::-1]
        
# Now populate two lists    
wf_origin = get_wf('http://www.gutenberg.org/files/1228/1228-h/1228-h.htm')
wf_Beagle = get_wf('http://www.gutenberg.org/cache/epub/944/pg944.html')
print wf_Beagle
# Out:
# [nltk_data] Downloading package 'stopwords' to /home/cosc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [(u'species', 282), (u'day', 284), (u'like', 286), (u'found', 303), (u'country', 310), (u'may', 315), (u'must', 331), (u'much', 334), (u'water', 342), (u'many', 368), (u'would', 377), (u'little', 411), (u'two', 480), (u'great', 506)]

# %%
#Plot the results: Darwin's Origin of Species versus The Voyage of the Beagle
import numpy as np
import pylab
import matplotlib.pyplot as plt

# %matplotlib inline
def plotTwoLists (wf_ee, wf_bu, title):
    f = plt.figure (figsize=(10, 6))
    # this is painfully tedious....
    f .suptitle (title, fontsize=20)
    ax = f.add_subplot(111)
    ax .spines ['top'] .set_color ('none')
    ax .spines ['bottom'] .set_color ('none')
    ax .spines ['left'] .set_color ('none')
    ax .spines ['right'] .set_color ('none')
    ax .tick_params (labelcolor='w', top='off', bottom='off', left='off', right='off', labelsize=20)

    # Create two subplots, this is the first one
    ax1 = f .add_subplot (121)
    plt .subplots_adjust (wspace=.5)

    pos = np .arange (len(wf_ee)+1) 
    ax1 .tick_params (axis='both', which='major', labelsize=14)
    pylab .yticks (pos, [ x [0] for x in wf_ee ])
    ax1 .barh (range(len(wf_ee)), [ x [1] for x in wf_ee ], align='center')

    ax2 = f .add_subplot (122)
    ax2 .tick_params (axis='both', which='major', labelsize=14)
    pos = np .arange (len(wf_bu)+1) 
    pylab .yticks (pos, [ x [0] for x in wf_bu ])
    ax2 .barh (range (len(wf_bu)), [ x [1] for x in wf_bu ], align='center')

plotTwoLists (wf_Beagle, wf_origin, 'Most Frequent Words From two of Darwin\'s Works')

# %% [markdown]
# # Problem 2
# The following code compares Homer's The Iliad to HG Well's The War of the Worlds

# %%
# Now to compare Homer's Iliad and HG Well's The War of the Worlds
wf_Iliad = get_wf('http://www.gutenberg.org/files/2199/2199-h/2199-h.htm')
wf_WotW = get_wf('http://www.gutenberg.org/files/36/36-h/36-h.htm')
print wf_WotW
# Out:
# [(u'men', 101), (u'us', 101), (u'little', 110), (u'man', 111), (u'could', 117), (u'time', 118), (u'black', 120), (u'saw', 128), (u'towards', 129), (u'came', 150), (u'martians', 156), (u'said', 160), (u'people', 160), (u'upon', 173)]

# %%
plotTwoLists (wf_Iliad, wf_WotW, 'Most Frequent Words From the Iliad and War of the Worlds')

# %% [markdown]
# # Problem 3
# Are there some words preferred by one author but used less frequently by another author?
#
# Based on the preceeding analysis, the similarity of most commonly occuring words appears to be more context specific than writer specific. There are many similarities in the most frequent words in Darwin's texts. Of the top 10 most commonly used words appear 4 words appear in both works with great (250+) frequency.  The Iliad and The War of the Worlds share fewer words (3), but if the Martians counted as Archeons (both invaders) then the number of similar words is th same.  A possible extension of this argument would find the proportion of times a word appears in the document.  This would control for different sized documents.
